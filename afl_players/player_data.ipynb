# %%
import requests
import pandas as pd

# %%
headers = {
    'sec-ch-ua': '^\\^Google',
    'Accept': 'application/json',
    'Referer': 'https://www.afl.com.au/',
    'x-media-mis-token': '6d3a826ba09520f556243bb98aa1a335',
    'sec-ch-ua-mobile': '?0',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.128 Safari/537.36',
    'Content-Type': 'application/x-www-form-urlencoded',
}

response = requests.get('https://api.afl.com.au/statspro/playersStats/seasons/CD_S2021014', headers=headers)

# %%
json_data = response.json()

# %%
player_data = json_data['players']

# %%
len(player_data)
# Out:
# 784

# %%
df = pd.json_normalize(player_data)

# %%
df.head()
# Out:
#       playerId  gamesPlayed playerDetails.givenName playerDetails.surname  \
# 0  CD_I1000044          0.0                     Jez              McLennan
# 1  CD_I1000061          0.0                  Callum         Coleman-Jones
# 2  CD_I1000068          3.0                   Chris               Burgess
# 3  CD_I1000072          5.0                    John                 Noble
# 4  CD_I1000223          5.0                    Liam                 Baker
#
#    playerDetails.age  playerDetails.heightCm  playerDetails.weightKg  \
# 0                 20                     185                      85
# 1                 21                     200                     105
# 2                 25                     191                      94
# 3                 24                     180                      73
# 4                 23                     173                      72
#
#    playerDetails.jumperNumber playerDetails.kickingFoot  \
# ...

# %%
df.to_csv('player_stats.csv', index=False)
