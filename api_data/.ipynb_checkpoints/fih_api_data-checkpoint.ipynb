# %%
import requests
import json

# %%
headers = {
    'Connection': 'keep-alive',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^88^\\^, ^\\^Google',
    'sec-ch-ua-mobile': '?0',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36',
    'Content-Type': 'application/json',
    'Accept': '*/*',
    'Origin': 'https://www.fihproleague.com',
    'Sec-Fetch-Site': 'cross-site',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Dest': 'empty',
    'Referer': 'https://www.fihproleague.com/',
    'Accept-Language': 'en-GB,en-US;q=0.9,en;q=0.8',
}

data = '^{^\\^perPage^\\^:^\\^200^\\^,^\\^page^\\^:1,^\\^competition_ids^\\^:^[1162,1163^],^\\^team_id^\\^:^[^],^\\^venus_id^\\^:^[^]^}'

response = requests.post('https://www.worldcup2018.hockey/admin/api/v1/matches/get-match-statics-list', headers=headers, data=data)

# %%
json_data = json.loads(response.text)

# %%
json_data
# Out:
# {'data': [{'id': 26,
#    'competition_id': 3,
#    'date': '1899-11-30',
#    'time': '00:00:00',
#    'datetimeutc': '1899-11-30 00:00:00',
#    'clock_started': '0',
#    'clock_elapsed': '0',
#    'period': None,
#    'status': 'Official',
#    'status2': 'Official',
#    'number': '12',
#    'venue': None,
#    'latitude': '',
#    'longitude': '',
#    'location': 'Amsterdam, Netherlands',
#    'ticket_link': '',
#    'timezone': None,
#    'currentTeamScore': 1,
#    'verseTeamScore': 0,
#    'homeps': 0,
#    'awayps': 0,
#    'title': None,
#    'hometitle': None,
#    'awaytitle': None,
#    'slug': '',
#    'live_link': '',
#    'matchDescription': '',
#    'currentTeam': {'id': 12,
#     'name': 'Belgium',
#     'code': 'BEL',
#     'standing': 4,
#     'ranking': None,
#     'fih_team_id': 9,
#     'coverPic': 'https://s3-us-west-1.amazonaws.com/fih-staging/Countries/cp_countries_15426485352525.jpg',
# ...

# %%
with open('fih_data.json', 'w') as json_file:
    json.dump(json_data, json_file)

# %%
with open('fih_data_beautified.json', 'w') as json_file:
    json_file.write(response.text)

# %% [markdown]
#  https://jsonformatter.curiousconcept.com/#
#
# JSON DATA FORMATTER
